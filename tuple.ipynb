# %%
m = ("apple", "banana", "cherry")
print(m[0])
print(m[2])
print(m[1:3])
# Out:
# apple
# cherry
# ('banana', 'cherry')

# %%
thistuple = ("apple", "banana", "cherry", "apple", "cherry")
print(thistuple)
# Out:
# ('apple', 'banana', 'cherry', 'apple', 'cherry')

# %%
thistuple = ("apple", "banana", "cherry")
print(len(thistuple))
# Out:
# 3

# %%
thistuple = ("apple",)
print(type(thistuple))

#NOT a tuple
thistuple = ("apple")
print(type(thistuple))
# Out:
# <class 'tuple'>
# <class 'str'>

# %%
tuple1 = ("apple", "banana", "cherry")
tuple2 = (1, 5, 7, 9, 3)
tuple3 = (True, False, False)
tuple8 = ("abc", 34, True, 40, "male")

# %%
thistuple = tuple(("apple", "banana", "cherry")) # note the double round-brackets
print(thistuple)
# Out:
# ('apple', 'banana', 'cherry')

# %%
thistuple = ("apple", "banana", "cherry")
print(thistuple[2])
# Out:
# cherry

# %%
t = ("apple", "banana", "cherry",11,80,"hi")
print(t[3])
print(t[-1])
print(t[-3])
print(t[:4])
print(t[2:])
print(t[-4:-1])
# Out:
# 11
# hi
# 11
# ('apple', 'banana', 'cherry', 11)
# ('cherry', 11, 80, 'hi')
# ('cherry', 11, 80)

# %%
t=("cscs","csdv","dsvdw")
if "csv" in t:
    print("y")
else:
    print(False)
# Out:
# False

# %%
x = ("apple", "banana", "cherry") #immutable
y = list(x) # tuple-->list
y[1] = "kiwi"
x = tuple(y)

print(x)
# Out:
# ('apple', 'kiwi', 'cherry')

# %%
x = ("apple", "banana", "cherry") 
y=list(x)
y.append("bjj")
print(tuple(y))
# Out:
# ('apple', 'banana', 'cherry', 'bjj')

# %%
x = ("apple", "banana", "cherry")
y=("dfs",)
x+=y
print(x)
z=x+y
print(z)
# Out:
# ('apple', 'banana', 'cherry', 'dfs')
# ('apple', 'banana', 'cherry', 'dfs', 'dfs')

# %%
x=("dss","dsd",10,40)
y=list(x)
y.remove(10)
print(tuple(y))
x=tuple(y)
print(x)
# Out:
# ('dss', 'dsd', 40)
# ('dss', 'dsd', 40)

# %%
x = ("dss","dsd",10,40)
del x

# %%
fruits = ("apple", "banana", "cherry")

(green, yellow, red) = fruits

print(green)
print(yellow)
print(red)
# Out:
# apple
# banana
# cherry

# %%
x=("s","d","r")
(hh,ii,oo)=x
print(ii)
# Out:
# d

# %%
x=("s","d","r")
(hh,ii,*oo)=x
print(oo)
# Out:
# ['r']

# %%
x=("s","d","r")
(hh,*ii,oo)=x
print(oo)
print(ii)
# Out:
# r
# ['d']

# %%
x=("s","d","r")
for i in x:
    print(i)
# Out:
# s
# d
# r

# %%
x=("s","d","r")
for i in range(len(x)):
    print(x[i])
# Out:
# s
# d
# r

# %%
x=("s","ddew","fwf")
i=0
while i < len(x):
    print(x[i])
    i=i+1
# Out:
# s
# ddew
# fwf

# %%
# JOIN TWO TUPLES
t1=("s","ddew","fwf")
t2=(1,2,3)
t3=t1+t2
print(t3)
# Out:
# ('s', 'ddew', 'fwf', 1, 2, 3)

# %%
t1=(10,2,3,4,2)
z=t1*2
print(z)
# Out:
# (10, 2, 3, 4, 2, 10, 2, 3, 4, 2)

# %%
#count()
#index()

# %%
set1={"fdf","dfg","buhij"}
print(set1)
# Out:
# {'buhij', 'fdf', 'dfg'}

# %%
a=[[1,2],[2,5,6,7],[4,7,]]
res=[x for sublist in a for x in sublist]
print(res)
# Out:
# [1, 2, 2, 5, 6, 7, 4, 7]

# %%
a=[1,4,[3,4,6],[9,8]]
b=[]
for i in a:
    if isinstance(i,list):
        b.extend(i)
    else:
        b.append(i)
print(b)
# Out:
# [1, 4, 3, 4, 6, 9, 8]

# %%
s={"df",1,True}
print(s)
r={2,0,False}
print(r)
print(len(r))
# Out:
# {'df', 1}
# {0, 2}
# 2

# %%
set1 = {"apple", "banana", "cherry"}
set2 = {1, 5, 7, 9, 3}
set3 = {True, False, False}

# %%
set1 = {"abc", 34, True, 40, "male"}
print(type(set1))
# Out:
# <class 'set'>

# %%
thisset = set(("apple", "banana", "cherry")) # note the double round-brackets
print(thisset)
# Out:
# {'cherry', 'apple', 'banana'}

# %%
set1 = {"abc", 34, True, 40, "male"}
for i in set1:
    print(i)
print("abc" in set1)
print("abc" not in set1)
# Out:
# True
# abc
# 34
# 40
# male
# True
# False

# %%
s = {"abc", 34, True, 40, "male"}
s.add(90)
s.add("fwefw")
print(s)
# Out:
# {True, 'abc', 34, 'fwefw', 40, 90, 'male'}

# %%
s = {"abc", 34, True, 40, "male"}
r=[11,3,45]
s.update(r)
print(s)
# Out:
# {True, 34, 3, 'abc', 'male', 40, 11, 45}

# %%
thisset = {"apple", "banana", "cherry"}
mylist = ["kiwi", "orange"]

thisset.update(mylist)

print(thisset)
# Out:
# {'cherry', 'apple', 'banana', 'kiwi', 'orange'}

# %%
t = {"apple", "banana", "cherry"}
t.remove("apple")
print(t)
# Out:
# {'cherry', 'banana'}

# %%
t = {"apple", "banana", "cherry"}
t.discard("apple")
print(t)
# Out:
# {'cherry', 'banana'}

# %%
t = {"apple", "banana", "cherry"}
r=t.pop()
print(r)
# Out:
# cherry

# %%
t = {"apple", "banana", "cherry"}
t.clear()
print(t)
# Out:
# set()

# %%
t = {"apple", "banana", "cherry"}
del t
print(t)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[37], line 3
#       1 t = {"apple", "banana", "cherry"}
#       2 del t
# ----> 3 print(t)
#
# NameError: name 't' is not defined

# %%
thisset = {"apple", "banana", "cherry"}

#

print(thisset)
# Out:
# {'cherry', 'apple', 'banana'}

# %%
s1 = {"a", "b", "c"}
s2 = {1, 2, 3}
s3=s1.union (s2)
print(s3)
# Out:
# {1, 2, 'c', 3, 'b', 'a'}

# %%
s1 = {"a", "b", "c"}
s2 = {1, 2, 3}
s3=s1|s2
print(s3)
# Out:
# {1, 2, 'c', 3, 'b', 'a'}

# %%
s1 = {"a", "b", "c"}
s2 = {1, 2, 3}
s3={"fdsfd","EF",22,45}
se=s1.union(s2,s3)
print(se)
# Out:
# {1, 2, 'c', 3, 'a', 45, 'EF', 'b', 22, 'fdsfd'}

# %%
s1 = {"a", "b", "c"}
s2 = {1, 2, 3}
s3={"fdsfd","EF",22,45}
x=s1|s2|s3
print(x)
# Out:
# {1, 2, 'c', 3, 'a', 45, 'EF', 'b', 22, 'fdsfd'}

# %%
x = {"a", "b", "c"}  #set
y = (1, 2, 3)  #tuple
z=x.union(y)
print(z)
# Out:
# {1, 2, 'c', 3, 'a', 'b'}

# %%
s1 = {"apple", "banana", "cherry"}
s2 = {"google", "microsoft", "apple"}
x=s1.intersection(s2)
print(x)
# Out:
# {'apple'}

# %%
s1 = {"apple", "banana", "cherry"}
s2 = {"google", "microsoft", "apple"}
x=s1&s2
print(x)
# Out:
# {'apple'}

# %%
set1 = {"apple", "banana", "cherry"}
set2 = {"google", "microsoft", "apple"}

set1.intersection_update(set2)

print(set1)
# Out:
# {'apple'}

# %%
set1 = {"apple", 1,  "banana", 0, "cherry"}
set2 = {False, "google",1, "apple", 2, True}

set3 = set1.intersection(set2)

print(set3)
# Out:
# {False, 1, 'apple'}

# %%
set1 = {"apple", "banana", "cherry"}
set2 = {"google", "microsoft", "apple"}

set3 = set2.difference(set1)

print(set3)
# Out:
# {'google', 'microsoft'}

# %%
set1 = {"apple", "banana", "cherry"}
set2 = {"google", "microsoft", "apple"}

set3 = set1 - set2
print(set3)
# Out:
# {'cherry', 'banana'}

# %%
set1 = {"apple", "banana", "cherry"}
set2 = {"google", "microsoft", "apple"}

set1.difference_update(set2)

print(set1)
# Out:
# {'cherry', 'banana'}

# %%
set1 = {"apple", "banana", "cherry"}
set2 = {"google", "microsoft", "apple"}

set3 = set1.symmetric_difference(set2)

print(set3)
# Out:
# {'cherry', 'google', 'banana', 'microsoft'}

# %%
set1 = {"apple", "banana", "cherry"}
set2 = {"google", "microsoft", "apple"}

set3 = set1 ^ set2
print(set3)
# Out:
# {'cherry', 'google', 'banana', 'microsoft'}

# %%
set1 = {"apple", "banana", "cherry"}
set2 = {"google", "microsoft", "apple"}

set1.symmetric_difference_update(set2)

print(set1)
# Out:
# {'cherry', 'google', 'banana', 'microsoft'}

# %%
s={1,2,3}
d={2,4,7}
x=s.symmetric_difference(d)
print(x)
# Out:
# {1, 3, 4, 7}

# %%
s={1,2,3}
d={2,4,7}
x=s^d
print(x)
# Out:
# {1, 3, 4, 7}

# %%
s={1,2,3}
d={2,4,7}
s.symmetric_difference_update(d)
print(s)
# Out:
# {1, 3, 4, 7}

# %%
x = frozenset({"cfe","er","fefr"})
print(x)
print(type(x))
# Out:
# frozenset({'cfe', 'fefr', 'er'})
# <class 'frozenset'>

# %%
y=frozenset({1,2})
print(y)
print(type(y))
# Out:
# frozenset({1, 2})
# <class 'frozenset'>

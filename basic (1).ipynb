# %%
print("Hello World")
# Out:
# Hello World

# %%
print("Riya is my name .")
# Out:
# Riya is my name .

# %%
print("my age is 23.")
# Out:
# my age is 23.

# %%
print(23)
print(23+25)
# Out:
# 23
# 48

# %%
print("rr")
# Out:
# rr

# %%
name="Riya"
age=23
price=99.25

# %%
print(name)
# Out:
# Riya

# %%
print(age)
# Out:
# 23

# %%
print("My name is :",name)
print("My age is :",age)
# Out:
# My name is : Riya
# My age is : 23

# %%
age2=age
print(age2)
# Out:
# 23

# %%
print(type(name))
print(type(age))
# Out:
# <class 'str'>
# <class 'int'>

# %%
print(type(price))
# Out:
# <class 'float'>

# %%
name1="rj"
name2='rj'
name3='''rj'''

# %%
print(name1)
print(name2)
print(name3)
# Out:
# rj
# rj
# rj

# %%
print(name1 , name2 , name3 )
# Out:
# rj rj rj

# %%
name='aaa'
name='bbbb'
name='ccc'
print(name)
# Out:
# ccc

# %%
age=23
old=False
a= None
print(type(old))
print(type(a))
# Out:
# <class 'bool'>
# <class 'NoneType'>

# %%
a=5
b=7
sum=a+b
print(sum)
# Out:
# 12

# %%
a=5
b=7
diff=a-b
print(diff)
# Out:
# -2

# %%
print("How are you ?") #Fine
# Out:
# How are you ?

# %% [markdown]
# Arithmetic Operator

# %%
a=5
b=2

# %%
print(a+b)
print(a-b)
print(a*b)
print(a/b)
print(a**b) #a^b
print(a%b)  #remainder
# Out:
# 7
# 3
# 10
# 2.5
# 25
# 1

# %% [markdown]
# Relational / Comaprison Operator

# %%
a=50
b=20

# %%
print(a==b)
print(a!=b)
print(a>=b)
print(a<=b)
# Out:
# False
# True
# True
# False

# %% [markdown]
# Assignment Operator

# %%
num=10
num = num+10
print(num)
# Out:
# 20

# %%
num=20
num+=30
print(num)
# Out:
# 50

# %% [markdown]
# Logical Operator

# %%
a=50
b=30
print(not False)
print(not(a>b))
# Out:
# True
# False

# %%
val1=True
val2=True
print("and operator :",val1 and val2)
# Out:
# and operator : True

# %%
val1=True
val2=False
print("and operator :",val1 and val2)
# Out:
# and operator : False

# %%
val1=False
val2=False
print("and operator :",val1 and val2)
# Out:
# and operator : False

# %%
val1=False
val2=True
print("and operator :",val1 and val2)
# Out:
# and operator : False

# %%
a=40
b=20
print("OR OPERATOR :",(a==b) or (a>b))
# Out:
# OR OPERATOR : True

# %% [markdown]
# # Type Conversion
